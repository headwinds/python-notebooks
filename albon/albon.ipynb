# %% [markdown]
# [Chris Albon](https://chrisalbon.com) has an awesome collection of article for aspiring data scientists.
#
# I want to visualize and track my progress through this link forest.
#
#
# credits
#
# [how-to-scrape-web-pages-with-beautiful-soup-and-python-3](https://www.digitalocean.com/community/tutorials/how-to-scrape-web-pages-with-beautiful-soup-and-python-3)

# %%
import csv
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# Collect first page of artists’ list
url = "https://chrisalbon.com/#articles"
page = requests.get(url)

soup = BeautifulSoup(page.text, 'html.parser')

# Pull all text from the BodyText div
cards = soup.find_all(class_='card')

# Create a file to write to, add headers row
f = csv.writer(open('albon.csv', 'w'))
f.writerow(['Name', 'Link', 'Category'])

titles = []
def getLinksFromCards(cards): 
    for card in cards:
        h4 = card.find('h4')
        # souph4 = BeautifulSoup("""<h1>Hello</h1><p>World</p>""", 'html.parser')
        category = str(h4)
        title = BeautifulSoup(category, 'html.parser').text.strip()
        print(title)
        titles.append(title)
        links = card.find_all('a')
        for link in links:
            # print(link.prettify())
            name = link.contents[0]
            link = link.get('href')
            # Add each artist’s name and associated link to a row
            f.writerow([name, link, title])
        
getLinksFromCards(cards)
# Out:
# Vectors, Matrices, And Arrays
# Basics
# Preprocessing Structured Data
# Preprocessing Images
# Preprocessing Text
# Preprocessing Dates And Times
# Feature Engineering
# Feature Selection
# Model Evaluation
# Model Selection
# Linear Regression
# Logistic Regression
# Trees And Forests
# Nearest Neighbors
# Support Vector Machines
# Naive Bayes
# Clustering
# Keras
# Basics
# Data Wrangling
# Data Visualization
# Web Scraping
# Testing
# Logging
# Other
# Frequentist
# None
# None
# Basics
# Add, Delete, Change Rows
# Merging And Joining
# Tables
# Text
# Numeric
# Dates
# None
# Basics
# S3 - CLI
# S3 - Boto
# Algorithms
# Basics
# Inputs And Outputs
# Search
# Text
# Flow Control
# Processes
# None

# %%
# Collect first page of names and meaning list
url = "https://www.momjunction.com/baby-names/norwegian/page/2/"
page = requests.get(url)

soup = BeautifulSoup(page.text, 'html.parser')

# Pull all text from the BodyText div
table = soup.find_all(class_='table')

for tr in soup.find_all('tr')[2:]:
    tds = tr.find_all('td')
    try:
        print ((tds[0].text, tds[1].text, tds[2].text))
        name = tds[0].text.strip()
        meaning = tds[1].text.strip()
        gender =  tds[2].text.strip()
    except IndexError:
        gotdata = 'null'
        
        
with open('names.txt', 'w') as f:
    for tr in soup.find_all('tr')[2:]:
        tds = tr.find_all('td')
        try:
            name = tds[0].text.strip()
            meaning = tds[1].text.strip()
            gender =  tds[2].text.strip()
            f.write("Name: %s, Meaning: %s, Gender: %s\n" % \
              (name, meaning, gender))        
        except IndexError:
            gotdata = 'null'
# Out:
# (' Erkengota', 'an ancient character of mythology.', 'Girl')
# (' Erling', 'heir of clanchief.', 'Boy')
# (' Ernaline', 'capable or serious or battle to the death.', 'Girl')
# (' Erneburga', 'a historical figure in Yorkshire.', 'Girl')
# (' Errika', 'one who rules eternally.', 'Girl')
# (' Eryk', 'someone who is a ruler for eternity.', 'Boy')
# (' Eryka', 'a feminized word which means someone who rules for eternity.', 'Girl')
# (' Eskil', 'god or divinity.', 'Boy')
# (' Esten', 'eastern town or island.', 'Boy')
# (' Estrith', 'a royal person of Norway.', 'Girl')
# (' Everton', 'a Norwegian word meaning wild boar.', 'Boy')
# (' Eyvind', 'The winner of the iselands', 'Boy')
# (' Finnigan', 'Descendants of the fair ones', 'Boy')
# (' Gydda', 'Aggressive, Destructive, Forceful', 'Girl')
# (' Gytha', 'Warlike, aggressive in doing everything', 'Girl')
# (' Haakon', 'High son, decendent', 'Boy')
# (' Haralds', "The war commander's son", 'Boy')
# (' Heorrenda', 'An army shield', 'Boy')
# (' Jannie', 'God is gracious', 'Girl')
# (' Jensynn', 'Junior Johannes or son of Johannes (God is gracious)', 'Boy')
# (' Kine', 'Kine means She is of Christian Faith', 'Girl')
# (' Kjell', 'Kjell means Cettle', 'Boy')
# (' Kjellaug', 'Kjellaug means Coundron of the Holy Oath', 'Girl')
# (' Kjersti', 'Version of Christina, means the Christian one', 'Girl')
# (' Kjerstin', 'Kjerstin means She is the Follower of Christ', 'Girl')
# (' Kjetil', 'Kjetil means Cauldron', 'Boy')
# (' Leif', 'A descendant, a person who is going to inherit', 'Boy')
# (' Lull', 'Woman who is a legendary soldier', 'Girl')
# (' Lulla', 'A legendary female warrior', 'Girl')
# (' Nikolina', 'One who achieves victory for people', 'Girl')
# (' Nils', 'Accomplishment or feat of the people.', 'Boy')
# (' Olef', "God's dedications, God's kindnesses.", 'Boy')
# (' Pussa', 'A tipsy person', 'Boy')
# (' Rebekka', 'A girl who traps and baits', 'Girl')
# (' Rebekkah', 'She who traps and baits people', 'Girl')
# (' Reginus', 'A male version of Regina. Means the King', 'Boy')
# (' Regna', 'To advise and to make a decision', 'Girl')
# (' Reidar', 'A warrior who fights for his home', 'Boy')
# (' Reidun', 'One who bestows the home', 'Girl')
# (' Reka', 'A mighty, distinguished person', 'Girl')
# (' Ronja', 'A daughter of a robber', 'Girl')
# (' Ronya', 'She who is a daughter of a robber', 'Girl')
# (' Rubert', 'One who has the glorious light', 'Boy')
# (' Runar', 'A magic, secret man', 'Boy')
# (' Rurik', 'A notable, legendary ruler', 'Boy')
# (' Sigge', 'He who is always victorious', 'Boy')
# (' Silje', 'A deminutive of Cecilia, meaning a blind woman', 'Girl')
# (' Sindre', 'One who is small and trivial. Also means a sparkling one', 'Boy')
# (' Siw', 'She who is a bride', 'Girl')
