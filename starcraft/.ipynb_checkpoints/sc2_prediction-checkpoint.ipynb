# %% [markdown]
# The INSA StarCraft 2 Player Prediction Challenge
#
# [link](https://www.kaggle.com/c/the-insa-starcraft-2-player-prediction-challenge/data)

# %% [raw]
# It is possible to determine who is playing given a behavioral trace (game events produced by the player) by designing a prediction model using machine learning techniques?
#
# 1. build features
# 2. train a model.
# 3. apply it on the test data
# 4. submit your result
#
# example row
# http://eu.battle.net/sc2/en/profile/4234852/1/First/,Protoss,Base,s,s,s,s,s,t5,Base,s,hotkey30,hotkey00,t10,t15

# %%
from IPython.core.display import display, HTML
from string import Template
import pandas as pd
file = './the-insa-starcraft-2-player-prediction-challenge/TRAIN.CSV'

# %%
# the-insa-starcraft-2-player-prediction-challenge/

# starcraft = pd.read_csv('./the-insa-starcraft-2-player-prediction-challenge/TRAIN.CSV')
# starcraft.head()


# https://stackoverflow.com/questions/34358196/read-csv-with-missing-incomplete-header-or-irregular-number-of-columns        

max = 100
count = 0
        
from tempfile import TemporaryFile
with open(file) as f, TemporaryFile("w+") as t:
    for line in f:
        t.write(line.replace(" ", ""))
    t.seek(0)
    ln = len(line.strip().split(","))
    header = t.readline().strip().split(",")
    header += range(ln)
    starcraft = pd.read_csv(t,names=header)
 
starcraft.head(10)
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py:709: UserWarning: Duplicate names specified. This will raise an error in the future.
#   return _read(filepath_or_buffer, kwds)
#   http://eu.battle.net/sc2/en/profile/4234852/1/First/  Protoss  Base  \
# 0  http://eu.battle.net/sc2/en/profile/3074362/1/...    Protoss     s
# 1  http://eu.battle.net/sc2/en/profile/4234852/1/...    Protoss  Base
# 2  http://eu.battle.net/sc2/en/profile/3074362/1/...    Protoss  Base
# 3  http://eu.battle.net/sc2/en/profile/4234852/1/...    Protoss  Base
# 4  http://eu.battle.net/sc2/en/profile/3074362/1/...    Protoss     s
# 5  http://eu.battle.net/sc2/en/profile/4234852/1/...    Protoss  Base
# 6  http://eu.battle.net/sc2/en/profile/3074362/1/...    Protoss  Base
# 7  http://eu.battle.net/sc2/en/profile/3401218/1/...    Protoss  Base
# 8  http://eu.battle.net/sc2/en/profile/2896854/1/...     Terran     s
# 9  http://eu.battle.net/sc2/en/profile/3401218/1/...    Protoss  Base
#
# ...

# %%
starcraft.columns
# Out:
# Index(['http://eu.battle.net/sc2/en/profile/4234852/1/First/',
#                                                     'Protoss',
#                                                        'Base',
#                                                           's',
#                                                         's.1',
#                                                         's.2',
#                                                         's.3',
#                                                         's.4',
#                                                          't5',
#                                                      'Base.1',
#        ...
#                                                          1625,
#                                                          1626,
#                                                          1627,
#                                                          1628,
#                                                          1629,
# ...

# %%
starcraft.describe()
# Out:
#        http://eu.battle.net/sc2/en/profile/4234852/1/First/  Protoss  Base  \
# count                                                3051       3051  3043
# unique                                                200          3     4
# top     http://kr.battle.net/sc2/en/profile/2348639/1/...    Protoss     s
# freq                                                   58       1209  1839
#
#            s   s.1   s.2   s.3   s.4    t5 Base.1 ...  1625 1626 1627 1628  \
# count   3043  3043  3043  3043  3043  3042   3041 ...   310  310  310  310
# unique    10    17    22    28    27    29     32 ...    32   30   33   47
# top        s     s     s     s     s     s      s ...     s    s    s    s
# freq    2756  2568  1769  1609  1173  1046    888 ...   106  105  116   99
#
#        1629 1630 1631 1632 1633 1634
# count   309  309  309  309  307  307
# unique   40   35   39   42   45   40
# top       s    s    s    s    s    s
# freq     94  100  103  104   98   95
#
# ...

# %%
import pandas as pd
import numpy as np
exam_data = [{'name':'Anastasia', 'score':12.5}, {'name':'Dima','score':9}, {'name':'Katherine','score':16.5}]
df = pd.DataFrame(exam_data)
for index, row in df.iterrows():
    print(row['name'], row['score'])
# Out:
# Anastasia 12.5
# Dima 9.0
# Katherine 16.5

# %%
for index, row in starcraft.iterrows():
    print(row[0])
# Out:
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# hotkey42
# nan
# nan
# nan
# nan
# nan
# nan
# s
# s
# nan
# hotkey62
# s
# s
# hotkey22
# hotkey12
# hotkey12
# hotkey22
# hotkey22
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# hotkey32
# t700
# t840
# s
# hotkey22
# hotkey62
# s
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# hotkey12
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# hotkey32
# nan
# nan
# nan
# s
# hotkey42
# hotkey42
# hotkey22
# s
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# s
# nan
# nan
# nan
# hotkey52
# nan
# hotkey32
# nan
# hotkey52
# nan
# nan
# hotkey42
# nan
# nan
# nan
# nan
# t740
# nan
# hotkey12
# nan
# hotkey12
# s
# hotkey42
# hotkey72
# hotkey22
# hotkey52
# t755
# nan
# hotkey62
# hotkey22
# t760
# s
# s
# hotkey32
# hotkey02
# hotkey12
# nan
# nan
# nan
# nan
# nan
# nan
# s
# s
# s
# nan
# nan
# nan
# nan
# nan
# nan
# hotkey82
# s
# nan
# nan
# s
# hotkey12
# nan
# hotkey42
# nan
# ...
