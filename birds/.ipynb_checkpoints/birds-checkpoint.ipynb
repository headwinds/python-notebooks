# %% [markdown]
# # Identify Birds using TFLearn
#
#
# WARNING: I could not get this example to run in python 3 because of the below decoding error!
#
# Data:
# [full_dataset.pkl](https://s3-us-west-2.amazonaws.com/ml-is-fun/data.zip)
#
#
# References:
#     Learning Multiple Layers of Features from Tiny Images, A. Krizhevsky, 2009.
# Links:
#     [Intro Article](https://medium.com/@ageitgey/machine-learning-is-fun-part-3-deep-learning-and-convolutional-neural-networks-f40359318721)
#     [Compliments Intro](https://bitfusion.io/2016/08/31/training-a-bird-classifier-with-tensorflow-and-tflearn/)
#     [TF Learn example](https://github.com/tflearn/tflearn/blob/master/examples/images/convnet_cifar10.py)
#     [CIFAR-10 Dataset](https://www.cs.toronto.edu/~kriz/cifar.html)
#     [next journal](https://nextjournal.com/a/17592186056126)
#     [stackoverflow on unicode in python](https://stackoverflow.com/questions/3224268/python-unicode-encode-error)
#
# Install:
#     * pip install tensorflow
#     * pip install tflearn
#     * no need to install pickle since it's built into python 3
#
#
# Alternative to full_dataset.pkl
#
# http://www.pythonexample.com/code/cifar-10---object-recognition-in-images/
#
# Gotchas:
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xa8 in position 6: ordinal not in range(128)
#
# export PYTHONIOENCODING=utf8
#
# https://stackoverflow.com/questions/2276200/changing-default-encoding-of-python/17628350#17628350
#
# https://stackoverflow.com/questions/20716812/saving-and-loading-multiple-objects-in-pickle-file

# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-

# Import tflearn and some helpers
import tflearn
from tflearn.data_utils import shuffle
from tflearn.layers.core import input_data, dropout, fully_connected
from tflearn.layers.conv import conv_2d, max_pool_2d
from tflearn.layers.estimator import regression
from tflearn.data_preprocessing import ImagePreprocessing
from tflearn.data_augmentation import ImageAugmentation
import pickle

#with open("full_dataset.pkl", "rb") as file_object:
#    X, Y, X_test, Y_test = pickle.load(file_object)

# Load the data set
def loadall(filename):
    with open(filename, "rb") as f:
        while True:
            try:
                result = 'hello'
                if type(pickle.load(f, encoding="utf-8")) == str:
                    # Ignore errors even if the string is not proper UTF-8 or has
                    # broken marker bytes.
                    # Python built-in function unicode() can do this.
                    result = unicode(pickle.load(f, encoding="utf-8"), "utf-8", errors="ignore")
                else:
                    # Assume the value object has proper __unicode__() method
                    result = unicode(pickle.load(f, encoding="utf-8"))
                print(result)
                return result
                
            except EOFError:
                break

X, Y, X_test, Y_test  = loadall("full_dataset.pkl")

# X, Y, X_test, Y_test = pickle.load(open("full_dataset.pkl", "rb"))

# Shuffle the data
X, Y = shuffle(X, Y)

# Make sure the data is normalized
img_prep = ImagePreprocessing()
img_prep.add_featurewise_zero_center()
img_prep.add_featurewise_stdnorm()

# Create extra synthetic training data by flipping, rotating and blurring the
# images on our data set.
img_aug = ImageAugmentation()
img_aug.add_random_flip_leftright()
img_aug.add_random_rotation(max_angle=25.)
img_aug.add_random_blur(sigma_max=3.)

# Define our network architecture:

# Input is a 32x32 image with 3 color channels (red, green and blue)
network = input_data(shape=[None, 32, 32, 3],
                     data_preprocessing=img_prep,
                     data_augmentation=img_aug)

# Step 1: Convolution
network = conv_2d(network, 32, 3, activation='relu')

# Step 2: Max pooling
network = max_pool_2d(network, 2)

# Step 3: Convolution again
network = conv_2d(network, 64, 3, activation='relu')

# Step 4: Convolution yet again
network = conv_2d(network, 64, 3, activation='relu')

# Step 5: Max pooling again
network = max_pool_2d(network, 2)

# Step 6: Fully-connected 512 node neural network
network = fully_connected(network, 512, activation='relu')

# Step 7: Dropout - throw away some data randomly during training to prevent over-fitting
network = dropout(network, 0.5)

# Step 8: Fully-connected neural network with two outputs (0=isn't a bird, 1=is a bird) to make the final prediction
network = fully_connected(network, 2, activation='softmax')

# Tell tflearn how we want to train the network
network = regression(network, optimizer='adam',
                     loss='categorical_crossentropy',
                     learning_rate=0.001)

# Wrap the network in a model object
model = tflearn.DNN(network, tensorboard_verbose=0, checkpoint_path='bird-classifier.tfl.ckpt')

# Train it! We'll do 100 training passes and monitor it as it goes.
model.fit(X, Y, n_epoch=100, shuffle=True, validation_set=(X_test, Y_test),
          show_metric=True, batch_size=96,
          snapshot_epoch=True,
          run_id='bird-classifier')

# Save model when training is complete to a file
model.save("bird-classifier.tfl")
print("Network trained and saved as bird-classifier.tfl!")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-5-60f2134c3913> in <module>
#      35                 break
#      36
# ---> 37 X, Y, X_test, Y_test  = loadall("full_dataset.pkl")
#      38
#      39 # X, Y, X_test, Y_test = pickle.load(open("full_dataset.pkl", "rb"))
#
# <ipython-input-5-60f2134c3913> in loadall(filename)
#      21             try:
#      22                 result = 'hello'
# ---> 23                 if type(pickle.load(f, encoding="utf-8")) == str:
#      24                     # Ignore errors even if the string is not proper UTF-8 or has
#      25                     # broken marker bytes.
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa8 in position 6: invalid start byte
