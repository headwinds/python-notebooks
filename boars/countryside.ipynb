# %%
# %load boar.py
import datetime as dt

print(dt.datetime.now())

# function with a defaut param


def hey(milk, time = dt.datetime.now()):
    return print(milk, time)

print(hey('chocobo'))
# Out:
# 2018-03-27 09:11:09.076661
# chocobo 2018-03-27 09:11:09.076844
# None

# %%
farmers = 10
fields = 4
revenue = farmers * fields * 10
print(revenue)
# Out:
# 400

# %%
def hello(word):
    print(word)
    total = add(farmers,fields)
    return total

def add(farmers,fields):
    return farmers + fields

def hello(*numbers):
    total = 0
    for n in numbers:
        total += n
    return total

print(hello(1,2,3,4,5,6))
# Out:
# 21

# %%
from IPython.display import SVG, display
def show_svg():
    display(SVG(url='https://upload.wikimedia.org/wikipedia/commons/b/b2/Dragon.svg'))
    
show_svg()

# %%
from IPython.core.display import HTML

# %%
HTML('''
<style scoped>
.scales{
color: green;
font: 28px script;
}
</style>
<div>

<h1 class='scales' style='letter-spacing:10'>DRAGON</h1></div>''')
# Out:
# <style scoped>
# .scales{
# color: green;
# font: 28px script;
# }
# </style>
# <div>
#
# <h1 class='scales' style='letter-spacing:10'>DRAGON</h1></div>
