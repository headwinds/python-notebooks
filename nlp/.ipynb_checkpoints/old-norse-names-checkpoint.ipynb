# %%
import csv
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# Collect first page of names and meaning list

norwegian_rows = []

def add_names(page_num): 
    """
    load name the html page and scrape the all the norwegian names, their meanings, and gender
    and add them to a csv file 
    """   
    norwegian_url = "https://www.momjunction.com/baby-names/norwegian/page/{page}/"
    # another interesting source
    # name_url = "http://www.babynames.net/all/sanskrit?page={page}"
    norwegian_page = requests.get(norwegian_url.format(page=page_num))
    norwegian_soup = BeautifulSoup(norwegian_page.text, 'html.parser')    
    for tr in norwegian_soup.find_all('tr')[2:]:
        tds = tr.find_all('td')
        try:
            name = tds[0].text
            meaning = tds[1].text
            gender =  tds[2].text
            norwegian_rows.append([name,meaning,gender])
            print (name, ",", meaning,",",gender)
            # writer.writerow([name, meaning, gender])
        except IndexError:
            gotdata = 'null' 
            
def write_csv():
    f = open('old_norwegian_names.csv', 'w')
    writer = csv.writer(f)
    writer.writerow(['Name', 'Meaning', 'Gender'])
    for row in norwegian_rows:
        name = row[0]
        meaning = row[1]
        gender =  row[2]
        writer.writerow([name, meaning, gender])
    f.close() 
 
    
def add_all_pages(total_pages):
    count = 0
    while count < total_pages:
        count += 1
        add_names(count)
    write_csv()    
        
add_all_pages(3)
# Out:
#  Emil , this means a person who is lively and eager. , Boy
#  Emilie , someone who is extremely laborious, hard working and striving. , Girl
#  Emma , the meaning of this name is universal whole. , Girl
#  Ingrid , Daughter of a hero , Girl
#  Ísak , Icelandic variant of Isaac, meaning he laughs. , Boy
#  Jacob , Hebrew - Yahweh may protect; Holder of Heel; Supplanter; Derived from the Yaakov or Yakubel in Hebrew , Boy
#  Lucas , One who gives light , Boy
#  Maya , Uncertain; Perhaps Mother or Great One; Illusion; Imaginative; Magical , Girl
#  Noah , Relaxation, restful, harmony, calm. , Unisex
#  Norah , The person who is possessing the quality of honourable. , Girl
#  Oliver , The one who represents the emblem of peace or olive tree. , Boy
#  Olivia , The one who is closer to olive tree. , Girl
#  Oskar , One with the fastness of a divine spear , Boy
#  Phillip , A friend and lover of horses , Boy
#  Sarah , Princess , Girl
#  Sophia , She who posesses great knoledge and wisdom , Girl
#  Sophie , She is wise and clever , Girl
#  William , Will or Desire to Protect , Boy
#  Ansfrid , Protected by God , Boy
#  Arild , War Chief, Battle Commander , Boy
#  Arwed , Eagle of the woods; a clear minded and has a good judgement , Boy
#  Asgrim , Name of a thief; leadership ability , Boy
#  Aud , Desorted or isolated , Girl
#  Audny , New prosperity , Girl
#  Beorhtel , He who shines with a bright light , Boy
#  Berdon , A Norwegian variant of Berton,Bergtor , Boy
#  Beret , A glorious and bright individual , Girl
#  Berrant , One who is like a strong bear , Boy
#  Bork , One who is killed by a gunnar , Boy
#  Borre , He who is a great help , Boy
#  Bragi , One who is considered as the God of Poetry , Boy
#  Brander , A fiery or sharp sword , Boy
#  Bugga , A man of power , Boy
#  Bugge , A powerful man , Boy
#  Eiel , one who is born to inspire fright , Boy
#  Eivind , Happy warrior; one who brings peace , Boy
#  Elias , One who believes Yahweh is the Lord , Boy
#  Erec , always mighty. , Boy
#  Erich , ruler of the people. , Boy
#  Erick , a word which means someone who rules the people. , Boy
#  Ericka , a feminized form of the name Erick meaning ruler of people. , Girl
#  Erickson , son of Erik; son of ruler. , Boy
#  Erico , someone who rules the people of a land. , Boy
#  Ericson , son of a ruler named Erik. , Boy
#  Erik , a ruler of the world. , Boy
#  Erika , a feminized form of the name Eric meaning someone who rules the world. , Girl
#  Erikka , a feminized word which means a ruler. , Girl
#  Erikson , son or Erik; ruler of the people. , Boy
#  Erix , island ruler or eternal ruler. , Boy
#  Erkengota , an ancient character of mythology. , Girl
#  Erling , heir of clanchief. , Boy
#  Ernaline , capable or serious or battle to the death. , Girl
#  Erneburga , a historical figure in Yorkshire. , Girl
#  Errika , one who rules eternally. , Girl
#  Eryk , someone who is a ruler for eternity. , Boy
#  Eryka , a feminized word which means someone who rules for eternity. , Girl
#  Eskil , god or divinity. , Boy
#  Esten , eastern town or island. , Boy
#  Estrith , a royal person of Norway. , Girl
#  Everton , a Norwegian word meaning wild boar. , Boy
#  Eyvind , The winner of the iselands , Boy
#  Finnigan , Descendants of the fair ones , Boy
#  Gydda , Aggressive, Destructive, Forceful , Girl
#  Gytha , Warlike, aggressive in doing everything , Girl
#  Haakon , High son, decendent , Boy
#  Haralds , The war commander's son , Boy
#  Heorrenda , An army shield , Boy
#  Jannie , God is gracious , Girl
#  Jensynn , Junior Johannes or son of Johannes (God is gracious) , Boy
#  Kine , Kine means She is of Christian Faith , Girl
#  Kjell , Kjell means Cettle , Boy
#  Kjellaug , Kjellaug means Coundron of the Holy Oath , Girl
#  Kjersti , Version of Christina, means the Christian one , Girl
#  Kjerstin , Kjerstin means She is the Follower of Christ , Girl
#  Kjetil , Kjetil means Cauldron , Boy
#  Leif , A descendant, a person who is going to inherit , Boy
#  Lull , Woman who is a legendary soldier , Girl
#  Lulla , A legendary female warrior , Girl
#  Nikolina , One who achieves victory for people , Girl
#  Nils , Accomplishment or feat of the people. , Boy
#  Olef , God's dedications, God's kindnesses. , Boy
#  Pussa , A tipsy person , Boy
#  Rebekka , A girl who traps and baits , Girl
#  Rebekkah , She who traps and baits people , Girl
#  Reginus , A male version of Regina. Means the King , Boy
#  Regna , To advise and to make a decision , Girl
#  Reidar , A warrior who fights for his home , Boy
#  Reidun , One who bestows the home , Girl
#  Reka , A mighty, distinguished person , Girl
#  Ronja , A daughter of a robber , Girl
#  Ronya , She who is a daughter of a robber , Girl
#  Rubert , One who has the glorious light , Boy
#  Runar , A magic, secret man , Boy
#  Rurik , A notable, legendary ruler , Boy
#  Sigge , He who is always victorious , Boy
#  Silje , A deminutive of Cecilia, meaning a blind woman , Girl
#  Sindre , One who is small and trivial. Also means a sparkling one , Boy
#  Siw , She who is a bride , Girl
#  Skule , One who likes to remain hidden , Boy
#  Snefrid , One who loves snow , Girl
#  Solfrid , She is beuatiful like the Sun , Girl
#  Solveig , She who has the strenght of the Sun , Girl
#  Sondre , One who comes from the South , Boy
#  Steinar , One who is a stone warrior , Boy
#  Svanhild , She fights with ellegant moves like a swan , Girl
#  Svante , Celebrating people , Boy
#  Sverre , To spin and swing wildly , Boy
#  Sylve , She who holds the strenght of the Sun , Girl
#  Tellef , Descendant of thunder , Boy
#  Teobald , A bold man , Boy
#  Thorsen , Son of Thor , Boy
#  Thorstein , Thor's stone , Boy
#  Tiril , The alluring sounds , Boy
#  Tollak , The play or game of weapons by Thor , Boy
#  Tone , A new thunder or storm , Girl
#  Torben , The bear of the thunder God , Boy
#  Torbjorg , The help or protection by the thunder God , Boy
#  Torbjorn , The bear of Thor , Boy
#  Tordis , The God who controls the thunder , Boy
#  Torhild , The battle of thunder god , Boy
#  Torild , The battle or war or Thor , Unisex
#  Torill , Thunder God's battle , Unisex
#  Torjus , The arrow or shaft or Thor , Boy
#  Trond , To thrive and grow, always increasing , Boy
#  Trygg , refers to protection or shelter or shield. , Boy
#  Trygve , A person who overcomes as a winner by his braveness. , Boy
#  Turpin , God of thunder, rain and farming. , Boy
#  Tuva , A beautiful lady, charming , Girl
